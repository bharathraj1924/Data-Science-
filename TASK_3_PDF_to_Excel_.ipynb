# %% [markdown]
# <a href="https://colab.research.google.com/github/bharathraj1924/Data-Science-/blob/main/TASK_3_PDF_to_Excel_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install tabula-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 30.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 465.3/465.3 kB 39.5 MB/s eta 0:00:00
# ...

# %%
pip install tabulate

# %%
import tabula as tb
pdf=tb.read_pdf('/content/drive/MyDrive/Test.pdf',pages='all')

# %%
import pandas as pd
pdf=pd.DataFrame(pdf[0])
# Out:
#      Pos              Player          Team       Span  Innings     Runs  \
# 0    NaN                 NaN           NaN        NaN      NaN      NaN
# 1    1.0     Sachin Tendular         India  1989-2012    452.0  18426.0
# 2    2.0    Kumar Sangakkara     Sri Lanka  2000-2015    380.0  14234.0
# 3    3.0       Ricky Ponting     Australia  1995-2012    365.0  13704.0
# 4    4.0   Sanath Jayasuriya     Sri Lanka  1989-2011    433.0  13430.0
# 5    5.0  Mahela Jayawardene     Sri Lanka  1998-2015    418.0  12650.0
# 6    6.0         Virat Kohli         India  2008-2020    236.0  11867.0
# 7    7.0      Inzamam-ul-Haq      Pakistan   1991-200    350.0  11739.0
# 8    8.0       Jacques Kalis  South Africa  1996-2014    314.0  11579.0
# 9    9.0      Saurav Ganguly         India  1992-2007    300.0  11363.0
# 10  10.0        Rahul Dravid         India  1996-2011    318.0  10889.0
#
#    Highest  Average Striking
# 0    Score      NaN     Rate
# 1      200    44.83    86.23
# ...

# %%
cric=pdf[1::]
cric.set_index('Pos',inplace=True)

# %%
cric
# Out:
#                   Player          Team       Span  Innings     Runs Highest  \
# Pos
# 1.0      Sachin Tendular         India  1989-2012    452.0  18426.0     200
# 2.0     Kumar Sangakkara     Sri Lanka  2000-2015    380.0  14234.0     169
# 3.0        Ricky Ponting     Australia  1995-2012    365.0  13704.0     164
# 4.0    Sanath Jayasuriya     Sri Lanka  1989-2011    433.0  13430.0     189
# 5.0   Mahela Jayawardene     Sri Lanka  1998-2015    418.0  12650.0     144
# 6.0          Virat Kohli         India  2008-2020    236.0  11867.0     183
# 7.0       Inzamam-ul-Haq      Pakistan   1991-200    350.0  11739.0     137
# 8.0        Jacques Kalis  South Africa  1996-2014    314.0  11579.0     139
# 9.0       Saurav Ganguly         India  1992-2007    300.0  11363.0     183
# 10.0        Rahul Dravid         India  1996-2011    318.0  10889.0     153
#
#       Average Striking
# Pos
# 1.0     44.83    86.23
# 2.0     41.98    78.86
# 3.0     42.03    80.39
# 4.0     32.36     91.2
# ...

# %%
cric.to_excel("cric.xlsx")
